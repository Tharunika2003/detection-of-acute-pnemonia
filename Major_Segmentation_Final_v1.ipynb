# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from tqdm import tqdm
import os
from cv2 import imread, createCLAHE
import cv2
from glob import glob
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
image_path = os.path.join("/content/drive/MyDrive/Major_Project_Pneumonia_Detection/D1/CXR_png")
mask_path = os.path.join("/content/drive/MyDrive/Major_Project_Pneumonia_Detection/D1/","masks/")

# %%
# we have 704 masks but 800 images. Hence we are going to
# make a 1-1 correspondance from mask to images, not the usual other way.
images = os.listdir(image_path)
mask = os.listdir(mask_path)
mask = [fName.split(".png")[0] for fName in mask]
image_file_name = [fName.split("_mask")[0] for fName in mask]

# %%
check = [i for i in mask if "mask" in i]
print("Total mask that has modified name:",len(check))
# Out:
# Total mask that has modified name: 566

# %%
testing_files = set(os.listdir(image_path)) & set(os.listdir(mask_path))
training_files = check

def getData(X_shape, flag = "test"):
    im_array = []
    mask_array = []

    if flag == "test":
        for i in tqdm(testing_files):
            im = cv2.resize(cv2.imread(os.path.join(image_path,i)),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i)),(X_shape,X_shape))[:,:,0]

            im_array.append(im)
            mask_array.append(mask)

        return im_array,mask_array

    if flag == "train":
        for i in tqdm(training_files):
            im = cv2.resize(cv2.imread(os.path.join(image_path,i.split("_mask")[0]+".png")),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i+".png")),(X_shape,X_shape))[:,:,0]

            im_array.append(im)
            mask_array.append(mask)

        return im_array,mask_array

# %%
#perform sanity check

def plotMask(X,y):
    sample = []

    for i in range(3):
        left = X[i]
        right = y[i]
        combined = np.hstack((left,right))
        sample.append(combined)


    for i in range(0,6,3):

        plt.figure(figsize=(25,10))

        plt.subplot(2,3,1+i)
        plt.imshow(sample[i])

        plt.subplot(2,3,2+i)
        plt.imshow(sample[i+1])


        plt.subplot(2,3,3+i)
        plt.imshow(sample[i+2])

        plt.show()

# %%
# Load training and testing data
dim = 256*2
X_train,y_train = getData(dim,flag="train")
X_test, y_test = getData(dim)
# Out:
# 100%|██████████| 566/566 [13:52<00:00,  1.47s/it]
# 100%|██████████| 138/138 [03:37<00:00,  1.58s/it]

# %%
print("training set")
plotMask(X_train,y_train)
print("testing set")
plotMask(X_test,y_test)
# Out:
# training set
# testing set

# %%
X_train = np.array(X_train).reshape(len(X_train),dim,dim,1)
y_train = np.array(y_train).reshape(len(y_train),dim,dim,1)
X_test = np.array(X_test).reshape(len(X_test),dim,dim,1)
y_test = np.array(y_test).reshape(len(y_test),dim,dim,1)
assert X_train.shape == y_train.shape
assert X_test.shape == y_test.shape
images = np.concatenate((X_train,X_test),axis=0)
mask  = np.concatenate((y_train,y_test),axis=0)

# %%
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras import backend as keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, LearningRateScheduler


def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet(input_size=(256,256,1)):
    inputs = Input(input_size)

    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])

# %% [markdown]
# #### Compile and train the Unet Model

# %%
model = unet(input_size=(512,512,1))
model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss,
                  metrics=[dice_coef, 'binary_accuracy'])
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 512, 512, 1)]        0         []
#
#  conv2d (Conv2D)             (None, 512, 512, 32)         320       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 512, 512, 32)         9248      ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 256, 256, 32)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 64)         18496     ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 64)         36928     ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 128, 128, 64)         0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 128)        73856     ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 128)        147584    ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 64, 64, 128)          0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 256)          295168    ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 256)          590080    ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 32, 32, 256)          0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 512)          1180160   ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 512)          2359808   ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 64, 64, 256)          524544    ['conv2d_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 64, 64, 512)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 64, 64, 256)          1179904   ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 64, 64, 256)          590080    ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 128, 128, 128)        131200    ['conv2d_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 128, 128, 256)        0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 128, 128, 128)        295040    ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 128)        147584    ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 256, 256, 64)         32832     ['conv2d_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 256, 256, 128)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 256, 256, 64)         73792     ['concatenate_2[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 256, 256, 64)         36928     ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 512, 512, 32)         8224      ['conv2d_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 512, 512, 64)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 512, 512, 32)         18464     ['concatenate_3[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 512, 512, 32)         9248      ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 512, 512, 1)          33        ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 7759521 (29.60 MB)
# Trainable params: 7759521 (29.60 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Callbacks, Early Stopping and Reduced LR

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('cxr_reg')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1,
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                                   patience=3,
                                   verbose=1, mode='min', epsilon=0.0001, cooldown=2, min_lr=1e-6)
early = EarlyStopping(monitor="val_loss",
                      mode="min",
                      patience=15)
callbacks_list = [checkpoint, early, reduceLROnPlat]
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
from IPython.display import clear_output
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split

model.compile(optimizer=Adam(lr=2e-4),
              loss=[dice_coef_loss],
           metrics = [dice_coef, 'binary_accuracy'])

train_vol, validation_vol, train_seg, validation_seg = train_test_split((images-127.0)/127.0,
                                                            (mask>127).astype(np.float32),
                                                            test_size = 0.1,random_state = 2042)

train_vol, test_vol, train_seg, test_seg = train_test_split(train_vol,train_seg,
                                                            test_size = 0.1,
                                                            random_state = 2042)

loss_history = model.fit(x = train_vol,
                       y = train_seg,
                         batch_size = 16,
                  epochs = 50,
                  validation_data =(test_vol,test_seg) ,
                  callbacks=callbacks_list)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9049 - dice_coef: 0.9055 - binary_accuracy: 0.9554
# Epoch 1: val_loss did not improve from -0.96488
# 36/36 [==============================] - 21s 329ms/step - loss: -0.9049 - dice_coef: 0.9055 - binary_accuracy: 0.9554 - val_loss: -0.9543 - val_dice_coef: 0.9543 - val_binary_accuracy: 0.9777 - lr: 0.0010
# Epoch 2/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9576 - dice_coef: 0.9576 - binary_accuracy: 0.9786
# Epoch 2: val_loss did not improve from -0.96488
# 36/36 [==============================] - 11s 314ms/step - loss: -0.9576 - dice_coef: 0.9576 - binary_accuracy: 0.9786 - val_loss: -0.9609 - val_dice_coef: 0.9609 - val_binary_accuracy: 0.9809 - lr: 0.0010
# Epoch 3/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9614 - dice_coef: 0.9615 - binary_accuracy: 0.9806
# Epoch 3: val_loss did not improve from -0.96488
# 36/36 [==============================] - 11s 306ms/step - loss: -0.9614 - dice_coef: 0.9615 - binary_accuracy: 0.9806 - val_loss: -0.9624 - val_dice_coef: 0.9624 - val_binary_accuracy: 0.9817 - lr: 0.0010
# Epoch 4/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9631 - dice_coef: 0.9631 - binary_accuracy: 0.9815
# Epoch 4: val_loss did not improve from -0.96488
# 36/36 [==============================] - 11s 308ms/step - loss: -0.9631 - dice_coef: 0.9631 - binary_accuracy: 0.9815 - val_loss: -0.9628 - val_dice_coef: 0.9628 - val_binary_accuracy: 0.9819 - lr: 0.0010
# Epoch 5/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9636 - dice_coef: 0.9637 - binary_accuracy: 0.9817
# Epoch 5: val_loss did not improve from -0.96488
# 36/36 [==============================] - 11s 315ms/step - loss: -0.9636 - dice_coef: 0.9637 - binary_accuracy: 0.9817 - val_loss: -0.9635 - val_dice_coef: 0.9635 - val_binary_accuracy: 0.9821 - lr: 0.0010
# Epoch 6/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9642 - dice_coef: 0.9643 - binary_accuracy: 0.9820
# Epoch 6: val_loss did not improve from -0.96488
# 36/36 [==============================] - 11s 317ms/step - loss: -0.9642 - dice_coef: 0.9643 - binary_accuracy: 0.9820 - val_loss: -0.9639 - val_dice_coef: 0.9639 - val_binary_accuracy: 0.9824 - lr: 0.0010
# Epoch 7/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9642 - dice_coef: 0.9642 - binary_accuracy: 0.9820
# Epoch 7: val_loss did not improve from -0.96488
# 36/36 [==============================] - 11s 314ms/step - loss: -0.9642 - dice_coef: 0.9642 - binary_accuracy: 0.9820 - val_loss: -0.9629 - val_dice_coef: 0.9629 - val_binary_accuracy: 0.9820 - lr: 0.0010
# Epoch 8/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9641 - dice_coef: 0.9642 - binary_accuracy: 0.9819
# Epoch 8: val_loss did not improve from -0.96488
# 36/36 [==============================] - 11s 307ms/step - loss: -0.9641 - dice_coef: 0.9642 - binary_accuracy: 0.9819 - val_loss: -0.9638 - val_dice_coef: 0.9638 - val_binary_accuracy: 0.9824 - lr: 0.0010
# Epoch 9/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9657 - dice_coef: 0.9657 - binary_accuracy: 0.9827
# Epoch 9: val_loss did not improve from -0.96488
# 36/36 [==============================] - 11s 310ms/step - loss: -0.9657 - dice_coef: 0.9657 - binary_accuracy: 0.9827 - val_loss: -0.9641 - val_dice_coef: 0.9641 - val_binary_accuracy: 0.9825 - lr: 0.0010
# Epoch 10/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9660 - dice_coef: 0.9660 - binary_accuracy: 0.9829
# Epoch 10: val_loss improved from -0.96488 to -0.96500, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 11s 314ms/step - loss: -0.9660 - dice_coef: 0.9660 - binary_accuracy: 0.9829 - val_loss: -0.9650 - val_dice_coef: 0.9650 - val_binary_accuracy: 0.9830 - lr: 0.0010
# Epoch 11/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9665 - dice_coef: 0.9666 - binary_accuracy: 0.9832
# Epoch 11: val_loss did not improve from -0.96500
# 36/36 [==============================] - 11s 312ms/step - loss: -0.9665 - dice_coef: 0.9666 - binary_accuracy: 0.9832 - val_loss: -0.9618 - val_dice_coef: 0.9618 - val_binary_accuracy: 0.9812 - lr: 0.0010
# Epoch 12/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9664 - dice_coef: 0.9665 - binary_accuracy: 0.9831
# Epoch 12: val_loss did not improve from -0.96500
# 36/36 [==============================] - 11s 312ms/step - loss: -0.9664 - dice_coef: 0.9665 - binary_accuracy: 0.9831 - val_loss: -0.9648 - val_dice_coef: 0.9648 - val_binary_accuracy: 0.9829 - lr: 0.0010
# Epoch 13/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9673 - dice_coef: 0.9671 - binary_accuracy: 0.9835
# Epoch 13: val_loss did not improve from -0.96500
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 36/36 [==============================] - 11s 317ms/step - loss: -0.9673 - dice_coef: 0.9671 - binary_accuracy: 0.9835 - val_loss: -0.9642 - val_dice_coef: 0.9642 - val_binary_accuracy: 0.9825 - lr: 0.0010
# Epoch 14/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9679 - dice_coef: 0.9678 - binary_accuracy: 0.9838
# Epoch 14: val_loss did not improve from -0.96500
# 36/36 [==============================] - 11s 315ms/step - loss: -0.9679 - dice_coef: 0.9678 - binary_accuracy: 0.9838 - val_loss: -0.9648 - val_dice_coef: 0.9648 - val_binary_accuracy: 0.9829 - lr: 5.0000e-04
# Epoch 15/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9689 - dice_coef: 0.9690 - binary_accuracy: 0.9843
# Epoch 15: val_loss did not improve from -0.96500
# 36/36 [==============================] - 11s 316ms/step - loss: -0.9689 - dice_coef: 0.9690 - binary_accuracy: 0.9843 - val_loss: -0.9642 - val_dice_coef: 0.9642 - val_binary_accuracy: 0.9827 - lr: 5.0000e-04
# Epoch 16/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9690 - dice_coef: 0.9691 - binary_accuracy: 0.9844
# Epoch 16: val_loss did not improve from -0.96500
# 36/36 [==============================] - 11s 308ms/step - loss: -0.9690 - dice_coef: 0.9691 - binary_accuracy: 0.9844 - val_loss: -0.9649 - val_dice_coef: 0.9649 - val_binary_accuracy: 0.9829 - lr: 5.0000e-04
# Epoch 17/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9688 - dice_coef: 0.9689 - binary_accuracy: 0.9842
# Epoch 17: val_loss did not improve from -0.96500
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 36/36 [==============================] - 11s 309ms/step - loss: -0.9688 - dice_coef: 0.9689 - binary_accuracy: 0.9842 - val_loss: -0.9649 - val_dice_coef: 0.9649 - val_binary_accuracy: 0.9829 - lr: 5.0000e-04
# Epoch 18/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9693 - dice_coef: 0.9694 - binary_accuracy: 0.9846
# Epoch 18: val_loss improved from -0.96500 to -0.96504, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 11s 312ms/step - loss: -0.9693 - dice_coef: 0.9694 - binary_accuracy: 0.9846 - val_loss: -0.9650 - val_dice_coef: 0.9650 - val_binary_accuracy: 0.9830 - lr: 2.5000e-04
# Epoch 19/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9700 - dice_coef: 0.9699 - binary_accuracy: 0.9849
# Epoch 19: val_loss did not improve from -0.96504
# 36/36 [==============================] - 11s 309ms/step - loss: -0.9700 - dice_coef: 0.9699 - binary_accuracy: 0.9849 - val_loss: -0.9648 - val_dice_coef: 0.9648 - val_binary_accuracy: 0.9829 - lr: 2.5000e-04
# Epoch 20/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9704 - dice_coef: 0.9703 - binary_accuracy: 0.9851
# Epoch 20: val_loss did not improve from -0.96504
# 36/36 [==============================] - 11s 315ms/step - loss: -0.9704 - dice_coef: 0.9703 - binary_accuracy: 0.9851 - val_loss: -0.9649 - val_dice_coef: 0.9649 - val_binary_accuracy: 0.9829 - lr: 2.5000e-04
# Epoch 21/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9707 - dice_coef: 0.9705 - binary_accuracy: 0.9852
# Epoch 21: val_loss did not improve from -0.96504
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 36/36 [==============================] - 11s 315ms/step - loss: -0.9707 - dice_coef: 0.9705 - binary_accuracy: 0.9852 - val_loss: -0.9649 - val_dice_coef: 0.9649 - val_binary_accuracy: 0.9830 - lr: 2.5000e-04
# Epoch 22/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9710 - dice_coef: 0.9710 - binary_accuracy: 0.9854
# Epoch 22: val_loss did not improve from -0.96504
# 36/36 [==============================] - 11s 309ms/step - loss: -0.9710 - dice_coef: 0.9710 - binary_accuracy: 0.9854 - val_loss: -0.9649 - val_dice_coef: 0.9649 - val_binary_accuracy: 0.9829 - lr: 1.2500e-04
# Epoch 23/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9713 - dice_coef: 0.9713 - binary_accuracy: 0.9855
# Epoch 23: val_loss did not improve from -0.96504
# 36/36 [==============================] - 11s 315ms/step - loss: -0.9713 - dice_coef: 0.9713 - binary_accuracy: 0.9855 - val_loss: -0.9646 - val_dice_coef: 0.9646 - val_binary_accuracy: 0.9827 - lr: 1.2500e-04
# Epoch 24/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9715 - dice_coef: 0.9716 - binary_accuracy: 0.9856
# Epoch 24: val_loss did not improve from -0.96504
# 36/36 [==============================] - 11s 309ms/step - loss: -0.9715 - dice_coef: 0.9716 - binary_accuracy: 0.9856 - val_loss: -0.9643 - val_dice_coef: 0.9643 - val_binary_accuracy: 0.9827 - lr: 1.2500e-04
# Epoch 25/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9716 - dice_coef: 0.9717 - binary_accuracy: 0.9857
# Epoch 25: val_loss did not improve from -0.96504
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 36/36 [==============================] - 11s 315ms/step - loss: -0.9716 - dice_coef: 0.9717 - binary_accuracy: 0.9857 - val_loss: -0.9649 - val_dice_coef: 0.9649 - val_binary_accuracy: 0.9829 - lr: 1.2500e-04
# Epoch 26/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9720 - dice_coef: 0.9721 - binary_accuracy: 0.9858
# Epoch 26: val_loss did not improve from -0.96504
# 36/36 [==============================] - 11s 315ms/step - loss: -0.9720 - dice_coef: 0.9721 - binary_accuracy: 0.9858 - val_loss: -0.9648 - val_dice_coef: 0.9648 - val_binary_accuracy: 0.9828 - lr: 6.2500e-05
# Epoch 27/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9720 - dice_coef: 0.9720 - binary_accuracy: 0.9859
# Epoch 27: val_loss did not improve from -0.96504
# 36/36 [==============================] - 11s 310ms/step - loss: -0.9720 - dice_coef: 0.9720 - binary_accuracy: 0.9859 - val_loss: -0.9646 - val_dice_coef: 0.9646 - val_binary_accuracy: 0.9827 - lr: 6.2500e-05
# Epoch 28/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9720 - dice_coef: 0.9722 - binary_accuracy: 0.9859
# Epoch 28: val_loss did not improve from -0.96504
# 36/36 [==============================] - 11s 310ms/step - loss: -0.9720 - dice_coef: 0.9722 - binary_accuracy: 0.9859 - val_loss: -0.9647 - val_dice_coef: 0.9647 - val_binary_accuracy: 0.9828 - lr: 6.2500e-05
# Epoch 29/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9721 - dice_coef: 0.9721 - binary_accuracy: 0.9860
# Epoch 29: val_loss did not improve from -0.96504
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 36/36 [==============================] - 11s 317ms/step - loss: -0.9721 - dice_coef: 0.9721 - binary_accuracy: 0.9860 - val_loss: -0.9649 - val_dice_coef: 0.9649 - val_binary_accuracy: 0.9829 - lr: 6.2500e-05
# Epoch 30/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9724 - dice_coef: 0.9724 - binary_accuracy: 0.9861
# Epoch 30: val_loss did not improve from -0.96504
# 36/36 [==============================] - 11s 313ms/step - loss: -0.9724 - dice_coef: 0.9724 - binary_accuracy: 0.9861 - val_loss: -0.9648 - val_dice_coef: 0.9648 - val_binary_accuracy: 0.9829 - lr: 3.1250e-05
# Epoch 31/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9724 - dice_coef: 0.9725 - binary_accuracy: 0.9861
# Epoch 31: val_loss did not improve from -0.96504
# 36/36 [==============================] - 11s 307ms/step - loss: -0.9724 - dice_coef: 0.9725 - binary_accuracy: 0.9861 - val_loss: -0.9646 - val_dice_coef: 0.9646 - val_binary_accuracy: 0.9828 - lr: 3.1250e-05
# Epoch 32/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9725 - dice_coef: 0.9724 - binary_accuracy: 0.9862
# Epoch 32: val_loss did not improve from -0.96504
# 36/36 [==============================] - 11s 316ms/step - loss: -0.9725 - dice_coef: 0.9724 - binary_accuracy: 0.9862 - val_loss: -0.9644 - val_dice_coef: 0.9644 - val_binary_accuracy: 0.9827 - lr: 3.1250e-05
# Epoch 33/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9726 - dice_coef: 0.9725 - binary_accuracy: 0.9862
# Epoch 33: val_loss did not improve from -0.96504
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 36/36 [==============================] - 11s 309ms/step - loss: -0.9726 - dice_coef: 0.9725 - binary_accuracy: 0.9862 - val_loss: -0.9644 - val_dice_coef: 0.9644 - val_binary_accuracy: 0.9826 - lr: 3.1250e-05

# %%
model.save('/content/drive/MyDrive/pneumonia/model.h5')

# %% [markdown]
# ## Plot the metric and evaluate

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 5))
ax1.plot(loss_history.history['loss'], '-', label = 'Loss')
ax1.plot(loss_history.history['val_loss'], '-', label = 'Validation Loss')
ax1.legend()

ax2.plot(100*np.array(loss_history.history['binary_accuracy']), '-',
         label = 'Accuracy')
ax2.plot(100*np.array(loss_history.history['val_binary_accuracy']), '-',
         label = 'Validation Accuracy')
ax2.legend()

# %% [markdown]
# ## Test the model

# %%
pred_candidates = np.random.randint(1,validation_vol.shape[0],10)
preds = model.predict(validation_vol)

plt.figure(figsize=(20,10))

for i in range(0,9,3):
    plt.subplot(3,3,i+1)

    plt.imshow(np.squeeze(validation_vol[pred_candidates[i]]))
    plt.xlabel("Base Image")


    plt.subplot(3,3,i+2)
    plt.imshow(np.squeeze(validation_seg[pred_candidates[i]]))
    plt.xlabel("Mask")

    plt.subplot(3,3,i+3)
    plt.imshow(np.squeeze(preds[pred_candidates[i]]))
    plt.xlabel("Prediction")
# Out:
# 3/3 [==============================] - 12s 1s/step
